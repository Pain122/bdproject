# %%
import pandas as pd

# %%
df = pd.read_csv("police.csv")

# %%
max(df[~df['Supervisor District'].isna()]['Supervisor District'].apply(lambda x: len(str(x))))
# Out:
# 4

# %%
df[~df['Current Police Districts'].isna()]['Current Police Districts']
# Out:
# 9         7.0
# 11        6.0
# 13        2.0
# 33        6.0
# 61        4.0
#          ...
# 727653    3.0
# 727654    4.0
# 727655    9.0
# 727656    6.0
# 727657    2.0
# Name: Current Police Districts, Length: 688032, dtype: float64

# %%
len(df.columns)
# Out:
# 35

# %%
set(df['Incident Code'])
# Out:
# {1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1062,
#  1133,
#  1160,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2020,
#  2101,
#  2102,
#  2103,
#  2104,
#  2201,
#  2202,
#  2203,
#  2204,
#  3011,
#  3012,
#  3013,
#  3014,
#  3021,
#  3022,
#  3023,
#  3024,
#  3031,
#  3032,
#  3033,
#  3034,
#  3041,
#  3042,
#  3043,
#  3044,
#  3051,
#  3052,
#  3053,
#  3054,
#  3061,
#  3062,
#  3063,
#  3064,
#  3071,
#  3072,
#  3073,
#  3074,
#  3081,
#  3082,
#  3083,
#  3084,
#  3091,
#  3092,
#  3093,
#  3094,
#  3401,
#  3411,
#  3412,
#  3413,
#  3414,
#  3421,
#  3422,
#  3423,
#  3424,
#  3431,
#  3432,
#  3433,
#  3434,
#  3441,
#  3442,
#  3443,
#  3444,
#  3451,
#  3452,
#  3453,
#  3454,
#  3461,
#  3462,
#  3463,
#  3464,
#  3471,
#  3472,
#  3473,
#  3474,
#  3481,
#  3483,
#  3484,
#  3491,
#  3492,
#  3493,
#  3494,
#  4011,
#  4012,
#  4013,
#  4014,
#  4021,
#  4022,
#  4023,
#  4024,
#  4026,
#  4033,
#  4051,
#  4052,
#  4053,
#  4054,
#  4061,
#  4062,
# ...

# %%
len('73006271000')
# Out:
# 11

# %%
max(df[~df['Current Police Districts'].isna()]['Current Police Districts'])
# Out:
# 10.0

# %%
df.columns
# Out:
# Index(['Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Report Datetime', 'Row ID', 'Incident ID',
#        'Incident Number', 'CAD Number', 'Report Type Code',
#        'Report Type Description', 'Filed Online', 'Incident Code',
#        'Incident Category', 'Incident Subcategory', 'Incident Description',
#        'Resolution', 'Intersection', 'CNN', 'Police District',
#        'Analysis Neighborhood', 'Supervisor District',
#        'Supervisor District 2012', 'Latitude', 'Longitude', 'Point',
#        'Neighborhoods', 'ESNCAG - Boundary File',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Civic Center Harm Reduction Project Boundary',
#        'HSOC Zones as of 2018-06-05', 'Invest In Neighborhoods (IIN) Areas',
#        'Current Supervisor Districts', 'Current Police Districts'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Incident Datetime                                        object
# Incident Date                                            object
# Incident Time                                            object
# Incident Year                                             int64
# Incident Day of Week                                     object
# Report Datetime                                          object
# Row ID                                                    int64
# Incident ID                                               int64
# Incident Number                                           int64
# CAD Number                                              float64
# Report Type Code                                         object
# Report Type Description                                  object
# Filed Online                                             object
# Incident Code                                             int64
# Incident Category                                        object
# ...

# %%
df.shape[0]
# Out:
# 727658

# %%
set(df['Incident Category'])
# Out:
# {'Arson',
#  'Assault',
#  'Burglary',
#  'Case Closure',
#  'Civil Sidewalks',
#  'Courtesy Report',
#  'Disorderly Conduct',
#  'Drug Offense',
#  'Drug Violation',
#  'Embezzlement',
#  'Fire Report',
#  'Forgery And Counterfeiting',
#  'Fraud',
#  'Gambling',
#  'Homicide',
#  'Human Trafficking (A), Commercial Sex Acts',
#  'Human Trafficking (B), Involuntary Servitude',
#  'Human Trafficking, Commercial Sex Acts',
#  'Larceny Theft',
#  'Liquor Laws',
#  'Lost Property',
#  'Malicious Mischief',
#  'Miscellaneous Investigation',
#  'Missing Person',
#  'Motor Vehicle Theft',
#  'Motor Vehicle Theft?',
#  'Non-Criminal',
#  'Offences Against The Family And Children',
#  'Other',
#  'Other Miscellaneous',
#  'Other Offenses',
#  'Prostitution',
#  'Rape',
#  'Recovered Vehicle',
#  'Robbery',
#  'Sex Offense',
#  'Stolen Property',
#  'Suicide',
#  'Suspicious',
#  'Suspicious Occ',
#  'Traffic Collision',
#  'Traffic Violation Arrest',
#  'Vandalism',
#  'Vehicle Impounded',
# ...

# %%
df.iloc[-1]
# Out:
# Incident Datetime                                                              2023/03/21 05:42:00 PM
# Incident Date                                                                              2023/03/21
# Incident Time                                                                                   17:42
# Incident Year                                                                                    2023
# Incident Day of Week                                                                          Tuesday
# Report Datetime                                                                2023/03/22 09:40:00 AM
# Row ID                                                                                   125676707021
# Incident ID                                                                                   1256767
# Incident Number                                                                             230201450
# ...

# %%
df['Incident Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Incident Category'>

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

# %%
corr = df.select_dtypes(include=numerics).corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 corr = df.select_dtypes(include=numerics).corr()
# ----> 2 corr.style.background_gradient(cmap='coolwarm').set_precision(2)
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
import seaborn as sns

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
set(df['Incident Day of Week'])
# Out:
# {'Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday'}

# %%
df.describe()
# Out:
#        Incident Year        Row ID   Incident ID  Incident Number
# count  727658.000000  7.276580e+05  7.276580e+05     7.276580e+05  \
# mean     2020.108594  9.468734e+10  9.468732e+05     2.026775e+08
# std         1.582119  1.883658e+10  1.883658e+05     1.632817e+07
# min      2018.000000  6.186871e+10  6.186870e+05     0.000000e+00
# 25%      2019.000000  7.839851e+10  7.839850e+05     1.902483e+08
# 50%      2020.000000  9.463348e+10  9.463345e+05     2.005143e+08
# 75%      2021.000000  1.109924e+11  1.109924e+06     2.162123e+08
# max      2023.000000  1.274410e+11  1.274409e+06     9.814243e+08
#
#          CAD Number  Incident Code           CNN  Supervisor District
# count  5.640120e+05  727658.000000  6.888140e+05        688435.000000  \
# mean   2.035483e+08   24561.526904  2.531727e+07             5.925562
# std    2.460650e+07   25631.116273  3.094454e+06             2.838556
# min    1.000000e+00    1000.000000  2.001300e+07             1.000000
# ...

# %%
for col in df.columns:
    print(f'{col} - {df[df[col].isna()].shape[0] / df.shape[0]* 100}')
# Out:
# Incident Datetime - 0.0
# Incident Date - 0.0
# Incident Time - 0.0
# Incident Year - 0.0
# Incident Day of Week - 0.0
# Report Datetime - 0.0
# Row ID - 0.0
# Incident ID - 0.0
# Incident Number - 0.0
# CAD Number - 22.489411234398577
# Report Type Code - 0.0
# Report Type Description - 0.0
# Filed Online - 79.81029549596101
# Incident Code - 0.0
# Incident Category - 0.08671656190133277
# Incident Subcategory - 0.08671656190133277
# Incident Description - 0.0
# Resolution - 0.0
# Intersection - 5.338222076854786
# CNN - 5.338222076854786
# Police District - 0.0
# Analysis Neighborhood - 5.356637321378999
# Supervisor District - 5.390306984874763
# Supervisor District 2012 - 5.354713340607813
# Latitude - 5.338222076854786
# Longitude - 5.338222076854786
# Point - 5.338222076854786
# Neighborhoods - 7.337650379711349
# ESNCAG - Boundary File - 98.9222959137397
# Central Market/Tenderloin Boundary Polygon - Updated - 87.14134937017116
# ...

# %%
any(df[['Row ID']].duplicated())
# Out:
# False

# %%
df.isna().sum().suduplicated
# Out:
# 4481295

# %%
df.shape[0] * df.shape[1]
# Out:
# 25468030

# %%
df.isna().sum().sum() / (df.shape[0] * df.shape[1])
# Out:
# 0.17595766142885808

# %%
df['Invest In Neighborhoods (IIN) Areas'].isna().sum() / df.shape[0]
# Out:
# 1.0

# %%
set(df['Incident Year'])
# Out:
# {2018, 2019, 2020, 2021, 2022, 2023}

# %%
sas = """CREATE EXTERNAL TABLE incidents_part_buck(
    inc_datetime STRING NOT NULL,
    inc_date STRING NOT NULL,
    inc_time STRING NOT NULL,
    inc_weekday STRING NOT NULL,
    rep_datetime STRING NOT NULL,
    row_id BIGINT PRIMARY KEY,
    inc_id INT NOT NULL,
    inc_number INT NOT NULL,
    cad_number FLOAT,
    rep_type_code STRING NOT NULL,
    rep_type_description STRING NOT NULL,
    filled_online BOOLEAN,
    inc_code INT NOT NULL,
    inc_category VARCHAR ( 44 ),
    inc_subcategory VARCHAR ( 40 ),
    inc_descr VARCHAR ( 84 ),
    resolution VARCHAR ( 20 ),
    intersection VARCHAR ( 84 ),
    cnn FLOAT,
    police_district VARCHAR ( 10 ),
    analysis_neigh VARCHAR ( 30 ),
    sup_distr FLOAT,
    sup_distr_2012 FLOAT,
    latitude FLOAT,
    longitude FLOAT,
    datapoint VARCHAR ( 46 ),
    neighbourhoods FLOAT,
    esncag FLOAT,
    cm_polygon FLOAT,
    cchr FLOAT,
    hsoc FLOAT,
    iin FLOAT,
    csd FLOAT,
    cpd FLOAT
) """

# %%
sas.replace('\n', '').replace('    ', ' ').replace(' NOT NULL', '')
# Out:
# 'CREATE EXTERNAL TABLE incidents_part_buck( inc_datetime STRING, inc_date STRING, inc_time STRING, inc_weekday STRING, rep_datetime STRING, row_id BIGINT PRIMARY KEY, inc_id INT, inc_number INT, cad_number FLOAT, rep_type_code STRING, rep_type_description STRING, filled_online BOOLEAN, inc_code INT, inc_category VARCHAR ( 44 ), inc_subcategory VARCHAR ( 40 ), inc_descr VARCHAR ( 84 ), resolution VARCHAR ( 20 ), intersection VARCHAR ( 84 ), cnn FLOAT, police_district VARCHAR ( 10 ), analysis_neigh VARCHAR ( 30 ), sup_distr FLOAT, sup_distr_2012 FLOAT, latitude FLOAT, longitude FLOAT, datapoint VARCHAR ( 46 ), neighbourhoods FLOAT, esncag FLOAT, cm_polygon FLOAT, cchr FLOAT, hsoc FLOAT, iin FLOAT, csd FLOAT, cpd FLOAT) '

# %%
sas.replace("CREATE EXTERNAL TABLE incidents_part_buck(", '').replace('\n', '').replace(' NOT NULL', '').replace('STRING', '').replace('PRIMARY KEY', "").replace('INT', "").replace('VARCHAR (', '').replace('FLOAT', "").replace(')', '').replace('    ', ' ')
# Out:
# ' inc_datetime , inc_date , inc_time , inc_weekday , rep_datetime , row_id BIG , inc_id , inc_number , cad_number , rep_type_code , rep_type_description , filled_online BOOLEAN, inc_code , inc_category  44 , inc_subcategory  40 , inc_descr  84 , resolution  20 , intersection  84 , cnn , police_district  10 , analysis_neigh  30 , sup_distr , sup_distr_2012 , latitude , longitude , datapoint  46 , neighbourhoods , esncag , cm_polygon , cchr , hsoc , iin , csd , cpd  '
